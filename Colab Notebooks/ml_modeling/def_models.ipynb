# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import warnings
import seaborn as sns
import statsmodels.api as sm

from scipy import stats
from scipy.stats import norm, skew, pearsonr
from sklearn.preprocessing import OneHotEncoder, scale, PolynomialFeatures
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.linear_model import LinearRegression, LassoCV, ElasticNetCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, VotingRegressor

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif

import plotly.express as px

seed = 55


# %matplotlib inline
# warnings.filterwarnings("ignore") # warnings were turned off at the end
sns.set_style("white")
pylab.rcParams['figure.figsize'] = 10, 8
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/My Drive/Capstone/Helpers/ML/')
from ml_helpers import *

# %%
# defenders = pd.read_pickle("../ml_data/defenders_final.pkl")
defenders = pd.read_pickle("/content/drive/My Drive/Capstone/Data/Clean/defenders_final.pkl").drop_duplicates(keep = False,ignore_index = True)
defenders.replace({"mid_seson": "mid_season"}, inplace = True)
defenders["type"] = defenders["type"].astype('object')

# %% [markdown]
# # Data Preperation

# %%
defenders["mv_log"] = np.log1p(defenders.mv)
defenders["cum_mv_log"] = np.log1p(defenders.cum_mv)

drop_cols = ["tm_id", "transfer_season","main_field_position","stats_season", "fee", "year", "mv", "cum_mv"]
cat_cols = ["type", "continent", "sf", "field_position"]

X,y = prepare_data(defenders, drop_cols, cat_cols)

# %%
encoded_cat_cols = X.select_dtypes('int64').columns

# %%
X_non_cat = X.drop(encoded_cat_cols, axis = 1)
X_non_cat = remove_corr(X_non_cat)
X = pd.concat([X[encoded_cat_cols],X_non_cat],axis = 1)
X
# Out:
#       tourn_year  x0_mid_season  x0_summer  ...  cum_winner     mv_log  cum_mv_log
# 0              0              0          1  ...         0.0  17.034386   16.677711
# 1              0              0          1  ...         0.0  13.527830   12.959847
# 2              0              0          1  ...         0.0  13.527830   13.527830
# 3              1              0          1  ...         0.0  13.592368    0.000000
# 4              1              0          1  ...         0.0  13.592368   13.592368
# ...          ...            ...        ...  ...         ...        ...         ...
# 1279           0              0          0  ...         0.0  13.815512    0.000000
# 1280           0              0          0  ...         0.0  13.815512    0.000000
# 1281           0              0          1  ...         0.0  14.187075   14.187075
# 1282           0              0          1  ...         2.0  15.068274   14.827112
# 1283           1              0          1  ...         0.0  13.815512   14.375127
#
# [1284 rows x 30 columns]

# %% [markdown]
# # Feature selection

# %% [markdown]
# ## Selecting features based on p value

# %%
X_non_cat = X.drop(encoded_cat_cols, axis = 1)
def_initial_ols = sm.OLS(y,X_non_cat).fit()
def_initial_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                fee_log   R-squared (uncentered):                   0.996
# Model:                            OLS   Adj. R-squared (uncentered):              0.996
# Method:                 Least Squares   F-statistic:                          1.559e+04
# Date:                Sun, 07 Jun 2020   Prob (F-statistic):                        0.00
# Time:                        13:54:12   Log-Likelihood:                         -1713.8
# No. Observations:                1284   AIC:                                      3466.
# Df Residuals:                    1265   BIC:                                      3564.
# Df Model:                          19
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# age              -0.1010      0.009    -11.257      0.000      -0.119      -0.083
# a                 0.0123      0.019      0.662      0.508      -0.024       0.049
# g                 0.0087      0.021      0.425      0.671      -0.032       0.049
# height            0.0168      0.002      8.641      0.000       0.013       0.021
# app               0.0070      0.003      2.388      0.017       0.001       0.013
# ppg               0.0360      0.048      0.752      0.452      -0.058       0.130
# rc                0.1215      0.080      1.518      0.129      -0.036       0.278
# fmpct            -0.1347      0.147     -0.915      0.360      -0.423       0.154
# mpyc           8.624e-06   7.52e-05      0.115      0.909      -0.000       0.000
# cum_games_won     0.0015      0.000      3.131      0.002       0.001       0.002
# cum_rc            0.0253      0.029      0.882      0.378      -0.031       0.082
# cum_mpyc          0.0003   9.16e-05      3.311      0.001       0.000       0.000
# cum_fmpct         0.0320      0.147      0.217      0.828      -0.257       0.321
# runner_up         0.0974      0.101      0.966      0.334      -0.100       0.295
# winner            0.0852      0.109      0.783      0.434      -0.128       0.299
# cum_runner_up    -0.0316      0.070     -0.451      0.652      -0.169       0.106
# cum_winner        0.0015      0.047      0.033      0.974      -0.090       0.093
# mv_log            0.9129      0.024     37.686      0.000       0.865       0.960
# cum_mv_log       -0.0045      0.006     -0.810      0.418      -0.015       0.006
# ==============================================================================
# Omnibus:                       23.024   Durbin-Watson:                   1.337
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.686
# Skew:                          -0.107   Prob(JB):                     2.41e-09
# Kurtosis:                       3.834   Cond. No.                     5.26e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.26e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
cols = significant_inputs(X_non_cat,y)
X = X[list(cols[1]) + list(encoded_cat_cols)]
X
# Out:
#        age   app  cum_games_won  ...  x2_both  x2_left  x2_no_info
# 0     21.0  34.0      41.892500  ...        0        0           0
# 1     18.0  26.0     102.290000  ...        0        0           0
# 2     18.0  26.0     102.290000  ...        0        0           0
# 3     20.0  17.0      31.991111  ...        0        0           0
# 4     20.0  17.0      31.991111  ...        0        0           0
# ...    ...   ...            ...  ...      ...      ...         ...
# 1279  28.0   8.0       5.335000  ...        0        0           0
# 1280  28.0  29.0       6.686667  ...        0        0           0
# 1281  21.0  19.0     122.915833  ...        0        1           0
# 1282  23.0  20.0      62.872500  ...        0        0           0
# 1283  26.0  17.0      93.517500  ...        0        0           0
#
# [1284 rows x 16 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = seed)

X_train.shape, X_test.shape, y_train.shape, y_test.shape,
# Out:
# ((1027, 16), (257, 16), (1027,), (257,))

# %% [markdown]
# # Polynomial Regression

# %%
reg_model = LinearRegression()

poly_predictors = PolynomialFeatures(degree = 2, interaction_only = True)
x_train_poly = poly_predictors.fit_transform(X_train)
x_test_poly = poly_predictors.fit_transform(X_test)
    
poly_model = LinearRegression()
poly_model_fit = poly_model.fit(x_train_poly, y_train)

# %% [markdown]
# # ElasticNet

# %%
elastic_model = ElasticNetCV(n_alphas = 500, cv = 5)
elastic_model.fit(X_train, y_train)
elastic_model.score(X_test, y_test)
# Out:
# 0.6366700704275412

# %% [markdown]
# # DTR

# %%
tune_tree_reg = DecisionTreeRegressor(random_state = 33)

tree_params = {
    "max_depth": np.arange(1,30),
    "min_samples_split": np.linspace(0.1, 1.0, 10, endpoint = True),
    "max_features": list(range(1,X_train.shape[1])),
}

tune_tree_reg_cv = GridSearchCV(tune_tree_reg, tree_params, cv = 5, scoring = "neg_mean_squared_error")
tune_tree_reg_cv.fit(X_train, y_train)

best_params = tune_tree_reg_cv.best_params_

tree_reg = DecisionTreeRegressor(max_depth = best_params["max_depth"], 
                                 min_samples_split= best_params["min_samples_split"],
                                 max_features = best_params["max_features"], random_state = 33)
tree_reg.fit(X_train, y_train)

tree_pred = tree_reg.predict(X_test)
rmse_tree = rmse(y_test, tree_pred)
r2_tree = r2_score(y_test, tree_pred)

# %% [markdown]
# # RFR

# %%
tune_rand_forest = RandomForestRegressor(random_state = 10)

rand_forest_params = {
    "n_estimators": [100,150,350,450,550],
}

tune_rand_forest_cv = GridSearchCV(tune_rand_forest, rand_forest_params, cv = 5, scoring = "neg_mean_squared_error")
tune_rand_forest_cv.fit(X_train, y_train)

best_forest_params = tune_rand_forest_cv.best_params_


tuned_rand_forest = RandomForestRegressor(n_estimators = best_forest_params["n_estimators"], random_state = 33)
tuned_rand_forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=450, n_jobs=None, oob_score=False,
#                       random_state=33, verbose=0, warm_start=False)

# %% [markdown]
# # Voting Regressor

# %%
voting_regressor = VotingRegressor([
    ("lr", reg_model),
    ("dt", tree_reg),
    ("rf", tuned_rand_forest),
    ("en", elastic_model)
])

# %% [markdown]
# # Summary

# %%
poly_model_df = model_summary([poly_model], x_train_poly, y_train, x_test_poly, y_test)
poly_model_df.loc[0,'model'] = "PolynomialRegression"

model_summary_df = model_summary([reg_model,
                                  tree_reg,
                                  tuned_rand_forest,
                                  elastic_model, 
                                  voting_regressor],X_train, y_train, X_test, y_test)

def_results_df = pd.concat([model_summary_df, poly_model_df])
def_results_df = def_results_df.sort_values(by = ["rmse_cv_mean"]).reset_index(drop=True)
def_results_df
# Out:
#                    model  train_r2  ...  rmse_cv_mean  r2_cv_mean
# 0  RandomForestRegressor  0.946481  ...       3124487    0.659802
# 1       LinearRegression  0.559143  ...       3529852    0.562871
# 2   PolynomialRegression  0.590897  ...       3576742    0.552401
# 3        VotingRegressor  0.721328  ...       3612032    0.544927
# 4           ElasticNetCV  0.549167  ...       3733384    0.507511
# 5  DecisionTreeRegressor  0.597552  ...       4059426    0.422195
#
# [6 rows x 7 columns]

# %%
def_results_df.to_pickle("/content/drive/My Drive/Capstone/Data/Summary/def_results.pkl")

# %%
rmse_fig = px.bar(def_results_df, x = 'rmse_cv_mean', y = 'model',
                  orientation = 'h', color = 'model', 
                  title = 'RMSE(CV) for each model - Defenders', 
                  labels = {'rmse_cv_mean': 'RMSE(cv)', 'model': 'Model used'})
rmse_fig.update_layout(showlegend=False)
rmse_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7801839e-873e-42c4-901c-63ed0cf981f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7801839e-873e-42c4-901c-63ed0cf981f0")) {
#                     Plotly.newPlot(
#                         '7801839e-873e-42c4-901c-63ed0cf981f0',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Model used=%{y}<br>RMSE(cv)=%{x}", "legendgroup": "Model used=RandomForestRegressor", "marker": {"color": "#636efa"}, "name": "Model used=RandomForestRegressor", "offsetgroup": "Model used=RandomForestRegressor", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [3124487], "xaxis": "x", "y": ["RandomForestRegressor"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Model used=%{y}<br>RMSE(cv)=%{x}", "legendgroup": "Model used=LinearRegression", "marker": {"color": "#EF553B"}, "name": "Model used=LinearRegression", "offsetgroup": "Model used=LinearRegression", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [3529852], "xaxis": "x", "y": ["LinearRegression"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Model used=%{y}<br>RMSE(cv)=%{x}", "legendgroup": "Model used=PolynomialRegression", "marker": {"color": "#00cc96"}, "name": "Model used=PolynomialRegression", "offsetgroup": "Model used=PolynomialRegression", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [3576742], "xaxis": "x", "y": ["PolynomialRegression"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Model used=%{y}<br>RMSE(cv)=%{x}", "legendgroup": "Model used=VotingRegressor", "marker": {"color": "#ab63fa"}, "name": "Model used=VotingRegressor", "offsetgroup": "Model used=VotingRegressor", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [3612032], "xaxis": "x", "y": ["VotingRegressor"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Model used=%{y}<br>RMSE(cv)=%{x}", "legendgroup": "Model used=ElasticNetCV", "marker": {"color": "#FFA15A"}, "name": "Model used=ElasticNetCV", "offsetgroup": "Model used=ElasticNetCV", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [3733384], "xaxis": "x", "y": ["ElasticNetCV"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Model used=%{y}<br>RMSE(cv)=%{x}", "legendgroup": "Model used=DecisionTreeRegressor", "marker": {"color": "#19d3f3"}, "name": "Model used=DecisionTreeRegressor", "offsetgroup": "Model used=DecisionTreeRegressor", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [4059426], "xaxis": "x", "y": ["DecisionTreeRegressor"], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %% [markdown]
# # Visualizing the best model's predictions

# %%
y_best_pred = tuned_rand_forest.predict(X_test)

# %%
chart_regression(y_best_pred.flatten(),y_test, scaled_back = True,
                 title="Defenders' actual and predicted prices",
                 y_axis="Price in Millions")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="798a0ff1-9ab8-43dd-95b3-043d3d810fc5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("798a0ff1-9ab8-43dd-95b3-043d3d810fc5")) {
#                     Plotly.newPlot(
#                         '798a0ff1-9ab8-43dd-95b3-043d3d810fc5',
#                         [{"mode": "lines", "name": "predicted", "type": "scatter", "x": [0.0, 0.00390625, 0.0078125, 0.01171875, 0.015625, 0.01953125, 0.0234375, 0.02734375, 0.03125, 0.03515625, 0.0390625, 0.04296875, 0.046875, 0.05078125, 0.0546875, 0.05859375, 0.0625, 0.06640625, 0.0703125, 0.07421875, 0.078125, 0.08203125, 0.0859375, 0.08984375, 0.09375, 0.09765625, 0.1015625, 0.10546875, 0.109375, 0.11328125, 0.1171875, 0.12109375, 0.125, 0.12890625, 0.1328125, 0.13671875, 0.140625, 0.14453125, 0.1484375, 0.15234375, 0.15625, 0.16015625, 0.1640625, 0.16796875, 0.171875, 0.17578125, 0.1796875, 0.18359375, 0.1875, 0.19140625, 0.1953125, 0.19921875, 0.203125, 0.20703125, 0.2109375, 0.21484375, 0.21875, 0.22265625, 0.2265625, 0.23046875, 0.234375, 0.23828125, 0.2421875, 0.24609375, 0.25, 0.25390625, 0.2578125, 0.26171875, 0.265625, 0.26953125, 0.2734375, 0.27734375, 0.28125, 0.28515625, 0.2890625, 0.29296875, 0.296875, 0.30078125, 0.3046875, 0.30859375, 0.3125, 0.31640625, 0.3203125, 0.32421875, 0.328125, 0.33203125, 0.3359375, 0.33984375, 0.34375, 0.34765625, 0.3515625, 0.35546875, 0.359375, 0.36328125, 0.3671875, 0.37109375, 0.375, 0.37890625, 0.3828125, 0.38671875, 0.390625, 0.39453125, 0.3984375, 0.40234375, 0.40625, 0.41015625, 0.4140625, 0.41796875, 0.421875, 0.42578125, 0.4296875, 0.43359375, 0.4375, 0.44140625, 0.4453125, 0.44921875, 0.453125, 0.45703125, 0.4609375, 0.46484375, 0.46875, 0.47265625, 0.4765625, 0.48046875, 0.484375, 0.48828125, 0.4921875, 0.49609375, 0.5, 0.50390625, 0.5078125, 0.51171875, 0.515625, 0.51953125, 0.5234375, 0.52734375, 0.53125, 0.53515625, 0.5390625, 0.54296875, 0.546875, 0.55078125, 0.5546875, 0.55859375, 0.5625, 0.56640625, 0.5703125, 0.57421875, 0.578125,
1040686.3983114096, 405088.7705717235, 1367777.3368448312, 756932.0019236172, 1075934.8133205625, 1212463.0617743717, 340348.227692571, 841387.9268867953, 1271220.6095700474, 366060.98994109116, 1154158.9614530972, 5311115.543162652, 1183206.8799588252, 4290201.034858031, 1751435.2439178457, 80846.97839158433, 307285.22597173695, 925228.8524818276, 540827.3245299459, 3035376.2223414974, 557964.5042141655, 470057.20524216566, 3661206.5535160964, 1506831.5662324408, 504559.6287824299, 587939.8487025158, 2229940.817806037, 377672.5503047883, 3827594.6584311672, 342771.64590125054, 831599.914582935, 969938.5581691056, 3935451.818310 ...
# Correlation between the variables 0.8487202583918848

# %%
imp_ft = pd.DataFrame({'feature':X_train.columns,'importance':tuned_rand_forest.feature_importances_})
imp_ft = imp_ft[imp_ft.importance != 0] 
imp_ft = imp_ft.sort_values(by = "importance", ascending = False)

fig_ft = px.bar(imp_ft, x = 'importance', y = 'feature',
       orientation = 'h', color = 'feature', 
       title = 'Importance of each feature in RFR', 
       labels = {'importance': 'Importance', 'feature': 'Feature'})
fig_ft.update_layout(showlegend=False)
fig_ft.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="972f134f-2040-42cc-ac5d-7a6a7f723bc1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("972f134f-2040-42cc-ac5d-7a6a7f723bc1")) {
#                     Plotly.newPlot(
#                         '972f134f-2040-42cc-ac5d-7a6a7f723bc1',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Feature=%{y}<br>Importance=%{x}", "legendgroup": "Feature=mv_log", "marker": {"color": "#636efa"}, "name": "Feature=mv_log", "offsetgroup": "Feature=mv_log", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0.5841761914658726], "xaxis": "x", "y": ["mv_log"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Feature=%{y}<br>Importance=%{x}", "legendgroup": "Feature=cum_mpyc", "marker": {"color": "#EF553B"}, "name": "Feature=cum_mpyc", "offsetgroup": "Feature=cum_mpyc", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0.09472249637347332], "xaxis": "x", "y": ["cum_mpyc"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Feature=%{y}<br>Importance=%{x}", "legendgroup": "Feature=age", "marker": {"color": "#00cc96"}, "name": "Feature=age", "offsetgroup": "Feature=age", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0.09193891468909664], "xaxis": "x", "y": ["age"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Feature=%{y}<br>Importance=%{x}", "legendgroup": "Feature=cum_games_won", "marker": {"color": "#ab63fa"}, "name": "Feature=cum_games_won", "offsetgroup": "Feature=cum_games_won", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0.09072830935707739], "xaxis": "x", "y": ["cum_games_won"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Feature=%{y}<br>Importance=%{x}", "legendgroup": "Feature=app", "marker": {"color": "#FFA15A"}, "name": "Feature=app", "offsetgroup": "Feature=app", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0.0849552794614595], "xaxis": "x", "y": ["app"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Feature=%{y}<br>Importance=%{x}", "legendgroup": "Feature=x0_summer", "marker": {"color": "#19d3f3"}, "name": "Feature=x0_summer", "offsetgroup": "Feature=x0_summer", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0.016943254950712836], "xaxis": "x", "y": ["x0_summer"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Feature=%{y}<br>Importance=%{x}", "legendgroup": "Feature=x2_left", "marker": {"color": "#FF6692"}, "name": "Feature=x2_left", "offsetgroup": "Feature=x2_left", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0.01230884257227158], "xaxis": "x", "y": ["x2_left"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Feature=%{y}<br>Importance=%{x}", "legendgroup": "Feature=tourn_year", "marker": {"color": "#B6E880"}, "name": "Feature=tourn_year", "offsetgroup": "Feature=tourn_year", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0.012177037175710196], "xaxis": "x", "y": ["tourn_year"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Feature=%{y}<br>Importance=%{x}", "legendgroup": "Feature=x1_EU", "marker": {"color": "#FF97FF"}, "name": "Feature=x1_EU", "offsetgroup": "Feature=x1_EU", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0.0120496739543259], "xaxis": "x", "y": ["x1_EU"], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type":

# %%
pd.DataFrame({"actual":y_test, "predicted":y_best_pred,"position":"Defenders"}).to_pickle("/content/drive/My Drive/Capstone/Data/Summary/def_predicted.pkl")
