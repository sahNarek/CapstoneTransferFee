# %%
import pandas as pd

# %%
def shorter_columns(df):
  df.columns = [("_").join(col.lower().split(" ")) for col in df.columns]
  df.columns = [col.replace('team', 'club') for col in df.columns]
  return df

# %%
df = pd.read_pickle("/content/drive/My Drive/Capstone/Data/Clean/trophies_Clean.pkl")
df = shorter_columns(df)
df.columns
df.to_pickle("/content/drive/My Drive/Capstone/Data/Clean/trophies_Clean.pkl")

# %%
df_1 = pd.read_pickle("/content/drive/My Drive/Capstone/Data/Clean/trophies_Clean.pkl")
df_1
# Out:
#             sofifa_id             competition     trophy     season
# Date
# 2014-06-30     158023               World Cup  Runner-up       2014
# 2014-06-30     158023          Copa Catalunya     Winner  2013/2014
# 2018-06-30     158023  Supercopa de Catalunya     Winner       2018
# 2007-06-30     158023          UEFA Super Cup  Runner-up  2006/2007
# 2006-06-30     158023     FIFA Club World Cup  Runner-up       2006
# ...               ...                     ...        ...        ...
# 2019-06-30     251124                 Copa MX  Runner-up  2018/2019
# 2017-06-30     251124              U17 League     Winner  2016/2017
# 2018-06-30     247002          First Division     Winner       2018
# 2018-06-30     243961              League Cup     Winner       2018
# 2019-06-30     251110                  FA Cup     Winner       2019
#
# [75936 rows x 4 columns]
