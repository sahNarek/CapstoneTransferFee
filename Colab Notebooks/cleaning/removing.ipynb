# %%
# !pip install dfply
# !pip install textdistance
import pandas as pd
import numpy as np
from datetime import datetime
import datetime as dt
from dateutil import parser
import textdistance
import re
import math
from dfply import *
from dateutil.relativedelta import *
from difflib import SequenceMatcher
# Out:
# ...
#      |████████████████████████████████| 614kB 1.4MB/s
# ...

# %%
sofifa = pd.read_pickle("/content/drive/My Drive/Capstone/Data/Clean/sofifa_head_Clean.pkl")
sofifa_long = pd.read_pickle("/content/drive/My Drive/Capstone/Data/Clean/sofifa_long_Clean.pkl")
players = pd.read_pickle("/content/drive/My Drive/Capstone/Data/Clean/Players_Clean.pkl")

# %%
sofifa_ids = players[players.sofifa_id.notnull()]["sofifa_id"]
len(sofifa_ids)
# Out:
# 11446

# %%
sofifa_clean = sofifa[sofifa.sofifa_id.isin(sofifa_ids)]
len(sofifa_clean.sofifa_id.unique())
sofifa_clean
# Out:
#        sofifa_id         short_name  ... wage_eur  game_year
# 0         158023           L. Messi  ...   565000 2020-01-01
# 1          20801  Cristiano Ronaldo  ...   405000 2020-01-01
# 2         190871          Neymar Jr  ...   290000 2020-01-01
# 3         200389           J. Oblak  ...   125000 2020-01-01
# 4         183277          E. Hazard  ...   470000 2020-01-01
# ...          ...                ...  ...      ...        ...
# 15426     223905              P. Ng  ...        0 2015-01-01
# 15454     194372        M. Taşkıran  ...        0 2015-01-01
# 15457     220939         L. Pilling  ...        0 2015-01-01
# 15458     222997           M. Maier  ...        0 2015-01-01
# 15463     222947          T. Davies  ...        0 2015-01-01
#
# [44150 rows x 24 columns]

# %%
sofifa_long = sofifa_long[sofifa_long.sofifa_id.isin(sofifa_ids)]
sofifa_long.set_index("game_year", drop=False, inplace = True)
sofifa_long
# Out:
#             sofifa_id   player_positions  ...       Attribute value
# game_year                                 ...
# 2015-01-01     158023               [CF]  ...            pace    93
# 2015-01-01      41236               [ST]  ...            pace    76
# 2015-01-01     176580           [ST, CF]  ...            pace    83
# 2015-01-01     167397               [ST]  ...            pace    77
# 2015-01-01     188350  [LM, RM, ST, CAM]  ...            pace    91
# ...               ...                ...  ...             ...   ...
# 2020-01-01     247224               [GK]  ...  gk_positioning    43
# 2020-01-01     251365               [GK]  ...  gk_positioning    48
# 2020-01-01     245408               [GK]  ...  gk_positioning    48
# 2020-01-01     248182               [GK]  ...  gk_positioning    47
# 2020-01-01     251789               [GK]  ...  gk_positioning    43
#
# [779703 rows x 7 columns]

# %%
sofifa_clean.to_pickle("/content/drive/My Drive/Capstone/Data/Clean/sofifa_headV2_Clean.pkl")
sofifa_long.to_pickle("/content/drive/My Drive/Capstone/Data/Clean/sofifa_longV2_Clean.pkl")
